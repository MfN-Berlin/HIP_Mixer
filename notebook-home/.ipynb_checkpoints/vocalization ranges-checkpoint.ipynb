# %%
voc_data <- read.csv("data//vocalization_f.csv")
voc_data
# Out:
#    Animal                  Taxonomy       min  max
# 1  Blue whale              Baleen whale     12    400
# 2  Fin whale               Baleen whale     14    118
# 3  Sei whale               Baleen whale     21   3000
# 4  Common minke whale      Baleen whale     50   9400
# 5  Humpback whale          Baleen whale     30  10000
# 6  Southern right whale    Baleen whale     30   2200
# 7  Arnoux's beaked whale   Toothed whale  1000   8500
# 8  Orca                    Toothed whale  1500  18000
# 9  Long-finned pilot whale Toothed whale  1000   8000
# 10 Sperm whale             Toothed whale   500  15000
# 11 Antarctic fur seal      Pinniped        100   8000
# 12 Crabeater seal          Pinniped        100   8000
# 13 Leopard seal            Pinniped         40   7000
# 14 Ross seal               Pinniped        140   4000
# 15 Weddell seal            Pinniped         50  15000
# 16 Dolphins and porpoises  Toothed whale  1000 150000

# %%
# plot ranges
library(ggplot2)
library(plyr)

#png("images/voc_ranges.png", width=1280, height=640, res=120)
ggplot(voc_data, aes(Animal, ymin = min, ymax = max, color = Taxonomy)) +
    geom_linerange(size = 4) + 
    scale_y_log10() +
    ylab("Vocalization frequency (Hz)") +
    coord_flip() 
#dev.off()
# Out:
# plot without title
